# %% [markdown]
# #PYTHONE PROJECT

# %%
import pandas as pd

# %%
import xlrd

# %%
data=pd.read_excel("data-06-PG.xls")

# %%
data.head(5)
# Out:
#    UniqueID  disbursed_amount  asset_cost    ltv  branch_id  supplier_id  \
# 0    420825             50578       58400  89.55         67        22807
# 1    537409             47145       65550  73.23         67        22807
# 2    417566             53278       61360  89.63         67        22807
# 3    624493             57513       66113  88.48         67        22807
# 4    539055             52378       60300  88.39         67        22807
#
#    manufacturer_id  Current_pincode_ID        Date.of.Birth Employment.Type  \
# 0               45                1441  1984-01-01 00:00:00        Salaried
# 1               45                1502             31-07-85   Self employed
# 2               45                1497             24-08-85   Self employed
# 3               45                1501             30-12-93   Self employed
# 4               45                1495  1977-09-12 00:00:00   Self employed
#
# ...

# %%
data.tail(5)
# Out:
#        UniqueID  disbursed_amount  asset_cost    ltv  branch_id  supplier_id  \
# 65530    464908             52303       64541  83.67          9        16120
# 65531    434034             52803       68929  78.34          9        16120
# 65532    433849             52999       74740  76.26          9        16120
# 65533    559443             57259       82172  70.58          9        16120
# 65534    626508             62213       82172  76.67          9        16120
#
#        manufacturer_id  Current_pincode_ID        Date.of.Birth  \
# 65530               86                5427  1987-10-10 00:00:00
# 65531               86                5448             22-12-98
# 65532               86                5427             28-09-86
# 65533               86                5461             13-10-85
# 65534               86                5461  1989-10-01 00:00:00
#
#       Employment.Type  ... SEC.SANCTIONED.AMOUNT  SEC.DISBURSED.AMOUNT  \
# ...

# %%
data.shape
# Out:
# (65535, 41)

# %%
data.columns
# Out:
# Index(['UniqueID', 'disbursed_amount', 'asset_cost', 'ltv', 'branch_id',
#        'supplier_id', 'manufacturer_id', 'Current_pincode_ID', 'Date.of.Birth',
#        'Employment.Type', 'DisbursalDate', 'State_ID', 'Employee_code_ID',
#        'MobileNo_Avl_Flag', 'Aadhar_flag', 'PAN_flag', 'VoterID_flag',
#        'Driving_flag', 'Passport_flag', 'PERFORM_CNS.SCORE',
#        'PERFORM_CNS.SCORE.DESCRIPTION', 'PRI.NO.OF.ACCTS', 'PRI.ACTIVE.ACCTS',
#        'PRI.OVERDUE.ACCTS', 'PRI.CURRENT.BALANCE', 'PRI.SANCTIONED.AMOUNT',
#        'PRI.DISBURSED.AMOUNT', 'SEC.NO.OF.ACCTS', 'SEC.ACTIVE.ACCTS',
#        'SEC.OVERDUE.ACCTS', 'SEC.CURRENT.BALANCE', 'SEC.SANCTIONED.AMOUNT',
#        'SEC.DISBURSED.AMOUNT', 'PRIMARY.INSTAL.AMT', 'SEC.INSTAL.AMT',
#        'NEW.ACCTS.IN.LAST.SIX.MONTHS', 'DELINQUENT.ACCTS.IN.LAST.SIX.MONTHS',
#        'AVERAGE.ACCT.AGE', 'CREDIT.HISTORY.LENGTH', 'NO.OF_INQUIRIES',
#        'loan_default'],
#       dtype='object')

# %%
data.dtypes
# Out:
# UniqueID                                 int64
# disbursed_amount                         int64
# asset_cost                               int64
# ltv                                    float64
# branch_id                                int64
# supplier_id                              int64
# manufacturer_id                          int64
# Current_pincode_ID                       int64
# Date.of.Birth                           object
# Employment.Type                         object
# DisbursalDate                           object
# State_ID                                 int64
# Employee_code_ID                         int64
# MobileNo_Avl_Flag                        int64
# Aadhar_flag                              int64
# PAN_flag                                 int64
# VoterID_flag                             int64
# Driving_flag                             int64
# Passport_flag                            int64
# PERFORM_CNS.SCORE                        int64
# ...

# %%
data.info
# Out:
# <bound method DataFrame.info of        UniqueID  disbursed_amount  asset_cost    ltv  branch_id  supplier_id  \
# 0        420825             50578       58400  89.55         67        22807
# 1        537409             47145       65550  73.23         67        22807
# 2        417566             53278       61360  89.63         67        22807
# 3        624493             57513       66113  88.48         67        22807
# 4        539055             52378       60300  88.39         67        22807
# ...         ...               ...         ...    ...        ...          ...
# 65530    464908             52303       64541  83.67          9        16120
# 65531    434034             52803       68929  78.34          9        16120
# 65532    433849             52999       74740  76.26          9        16120
# 65533    559443             57259       82172  70.58          9        16120
# 65534    626508             62213       82172  76.67          9        16120
#
# ...

# %%
data.isna()
# Out:
#        UniqueID  disbursed_amount  asset_cost    ltv  branch_id  supplier_id  \
# 0         False             False       False  False      False        False
# 1         False             False       False  False      False        False
# 2         False             False       False  False      False        False
# 3         False             False       False  False      False        False
# 4         False             False       False  False      False        False
# ...         ...               ...         ...    ...        ...          ...
# 65530     False             False       False  False      False        False
# 65531     False             False       False  False      False        False
# 65532     False             False       False  False      False        False
# 65533     False             False       False  False      False        False
# 65534     False             False       False  False      False        False
#
# ...

# %%
data.isna().sum()
# Out:
# UniqueID                                  0
# disbursed_amount                          0
# asset_cost                                0
# ltv                                       0
# branch_id                                 0
# supplier_id                               0
# manufacturer_id                           0
# Current_pincode_ID                        0
# Date.of.Birth                             0
# Employment.Type                        2658
# DisbursalDate                             0
# State_ID                                  0
# Employee_code_ID                          0
# MobileNo_Avl_Flag                         0
# Aadhar_flag                               0
# PAN_flag                                  0
# VoterID_flag                              0
# Driving_flag                              0
# Passport_flag                             0
# PERFORM_CNS.SCORE                         0
# PERFORM_CNS.SCORE.DESCRIPTION             0
# ...

# %%
data1=data.drop(['Employment.Type','Date.of.Birth','DisbursalDate'],axis=1)

# %%
data1.isna().sum()
# Out:
# UniqueID                               0
# disbursed_amount                       0
# asset_cost                             0
# ltv                                    0
# branch_id                              0
# supplier_id                            0
# manufacturer_id                        0
# Current_pincode_ID                     0
# State_ID                               0
# Employee_code_ID                       0
# MobileNo_Avl_Flag                      0
# Aadhar_flag                            0
# PAN_flag                               0
# VoterID_flag                           0
# Driving_flag                           0
# Passport_flag                          0
# PERFORM_CNS.SCORE                      0
# PERFORM_CNS.SCORE.DESCRIPTION          0
# PRI.NO.OF.ACCTS                        0
# PRI.ACTIVE.ACCTS                       0
# PRI.OVERDUE.ACCTS                      0
# PRI.CURRENT.BALANCE                    0
# PRI.SANCTIONED.AMOUNT                  0
# ...

# %%
display(data1)
# Out:
#        UniqueID  disbursed_amount  asset_cost    ltv  branch_id  supplier_id  \
# 0        420825             50578       58400  89.55         67        22807
# 1        537409             47145       65550  73.23         67        22807
# 2        417566             53278       61360  89.63         67        22807
# 3        624493             57513       66113  88.48         67        22807
# 4        539055             52378       60300  88.39         67        22807
# ...         ...               ...         ...    ...        ...          ...
# 65530    464908             52303       64541  83.67          9        16120
# 65531    434034             52803       68929  78.34          9        16120
# 65532    433849             52999       74740  76.26          9        16120
# 65533    559443             57259       82172  70.58          9        16120
# 65534    626508             62213       82172  76.67          9        16120
#
# ...

# %%
data1.describe()
# Out:
#             UniqueID  disbursed_amount     asset_cost           ltv  \
# count   65535.000000      65535.000000   65535.000000  65535.000000
# mean   536026.870603      53726.987961   75882.391684     73.890214
# std     68680.552181      12142.777363   17435.491746     11.747705
# min    417428.000000      13369.000000   38500.000000     10.030000
# 25%    475657.500000      46749.000000   66166.000000     67.670000
# 50%    536264.000000      53303.000000   71260.000000     75.740000
# 75%    596547.500000      59713.000000   79119.000000     83.010000
# max    658675.000000     166972.000000  264500.000000     95.000000
#
#           branch_id   supplier_id  manufacturer_id  Current_pincode_ID  \
# count  65535.000000  65535.000000     65535.000000        65535.000000
# mean      55.826062  18996.074861        68.776440         3722.998688
# std       55.842898   3271.356250        21.599848         2194.808762
# ...

# %% [markdown]
#  ## DATA PREPROCESSING

# %% [markdown]
# # label encoding

# %%
from sklearn import preprocessing as p

# %%
data1["PERFORM_CNS.SCORE.DESCRIPTION"]
# Out:
# 0        No Bureau History Available
# 1                      I-Medium Risk
# 2        No Bureau History Available
# 3                   L-Very High Risk
# 4        No Bureau History Available
#                     ...
# 65530    No Bureau History Available
# 65531    No Bureau History Available
# 65532    No Bureau History Available
# 65533    No Bureau History Available
# 65534    No Bureau History Available
# Name: PERFORM_CNS.SCORE.DESCRIPTION, Length: 65535, dtype: object

# %%
data1["PERFORM_CNS.SCORE.DESCRIPTION"].unique()
# Out:
# array(['No Bureau History Available', 'I-Medium Risk', 'L-Very High Risk',
#        'A-Very Low Risk',
#        'Not Scored: Not Enough Info available on the customer',
#        'D-Very Low Risk', 'M-Very High Risk', 'B-Very Low Risk',
#        'C-Very Low Risk', 'E-Low Risk', 'H-Medium Risk', 'F-Low Risk',
#        'K-High Risk',
#        'Not Scored: No Activity seen on the customer (Inactive)',
#        'Not Scored: Sufficient History Not Available',
#        'Not Scored: No Updates available in last 36 months', 'G-Low Risk',
#        'J-High Risk', 'Not Scored: Only a Guarantor',
#        'Not Scored: More than 50 active Accounts found'], dtype=object)

# %%
encoder=p.LabelEncoder()

# %%
encoder.fit(data1["PERFORM_CNS.SCORE.DESCRIPTION"])
# Out:
# LabelEncoder()

# %%
encoder.transform(data1["PERFORM_CNS.SCORE.DESCRIPTION"])
# Out:
# array([13,  8, 13, ..., 13, 13, 13])

# %%
coded=encoder.transform(data1["PERFORM_CNS.SCORE.DESCRIPTION"])

# %%
coded
# Out:
# array([13,  8, 13, ..., 13, 13, 13])

# %%
encoder.inverse_transform(coded)
# Out:
# array(['No Bureau History Available', 'I-Medium Risk',
#        'No Bureau History Available', ..., 'No Bureau History Available',
#        'No Bureau History Available', 'No Bureau History Available'],
#       dtype=object)

# %%
encoder.classes_
# Out:
# array(['A-Very Low Risk', 'B-Very Low Risk', 'C-Very Low Risk',
#        'D-Very Low Risk', 'E-Low Risk', 'F-Low Risk', 'G-Low Risk',
#        'H-Medium Risk', 'I-Medium Risk', 'J-High Risk', 'K-High Risk',
#        'L-Very High Risk', 'M-Very High Risk',
#        'No Bureau History Available',
#        'Not Scored: More than 50 active Accounts found',
#        'Not Scored: No Activity seen on the customer (Inactive)',
#        'Not Scored: No Updates available in last 36 months',
#        'Not Scored: Not Enough Info available on the customer',
#        'Not Scored: Only a Guarantor',
#        'Not Scored: Sufficient History Not Available'], dtype=object)

# %%
data1["AVERAGE.ACCT.AGE"]
# Out:
# 0         0yrs 0mon
# 1        1yrs 11mon
# 2         0yrs 0mon
# 3         0yrs 8mon
# 4         0yrs 0mon
#             ...
# 65530     0yrs 0mon
# 65531     0yrs 0mon
# 65532     0yrs 0mon
# 65533     0yrs 0mon
# 65534     0yrs 0mon
# Name: AVERAGE.ACCT.AGE, Length: 65535, dtype: object

# %%
data1["AVERAGE.ACCT.AGE"].unique()
# Out:
# array(['0yrs 0mon', '1yrs 11mon', '0yrs 8mon', '1yrs 9mon', '0yrs 2mon',
#        '4yrs 8mon', '1yrs 7mon', '0yrs 7mon', '2yrs 1mon', '1yrs 3mon',
#        '1yrs 0mon', '3yrs 11mon', '0yrs 1mon', '2yrs 6mon', '1yrs 10mon',
#        '0yrs 11mon', '0yrs 6mon', '2yrs 9mon', '3yrs 1mon', '2yrs 0mon',
#        '0yrs 4mon', '1yrs 1mon', '0yrs 5mon', '2yrs 10mon', '3yrs 9mon',
#        '1yrs 2mon', '12yrs 10mon', '0yrs 10mon', '1yrs 6mon', '2yrs 5mon',
#        '3yrs 8mon', '2yrs 3mon', '1yrs 5mon', '2yrs 8mon', '0yrs 9mon',
#        '3yrs 0mon', '7yrs 3mon', '4yrs 4mon', '1yrs 4mon', '0yrs 3mon',
#        '1yrs 8mon', '3yrs 4mon', '3yrs 5mon', '4yrs 7mon', '2yrs 7mon',
#        '2yrs 4mon', '3yrs 10mon', '5yrs 6mon', '2yrs 2mon', '3yrs 3mon',
#        '4yrs 0mon', '4yrs 10mon', '9yrs 10mon', '5yrs 0mon', '5yrs 1mon',
#        '4yrs 11mon', '6yrs 2mon', '10yrs 3mon', '6yrs 11mon', '4yrs 6mon',
#        '4yrs 5mon', '6yrs 8mon', '6yrs 5mon', '5yrs 3mon', '4yrs 1mon',
# ...

# %%
encoder=p.LabelEncoder()

# %%
encoder.fit(data1["AVERAGE.ACCT.AGE"])
# Out:
# LabelEncoder()

# %%
encoder.transform(data1["AVERAGE.ACCT.AGE"])
# Out:
# array([ 0, 57,  0, ...,  0,  0,  0])

# %%
coded=encoder.transform(data1["AVERAGE.ACCT.AGE"])

# %%
coded
# Out:
# array([ 0, 57,  0, ...,  0,  0,  0])

# %%
encoder.inverse_transform(coded)
# Out:
# array(['0yrs 0mon', '1yrs 11mon', '0yrs 0mon', ..., '0yrs 0mon',
#        '0yrs 0mon', '0yrs 0mon'], dtype=object)

# %%
encoder.classes_
# Out:
# array(['0yrs 0mon', '0yrs 10mon', '0yrs 11mon', '0yrs 1mon', '0yrs 2mon',
#        '0yrs 3mon', '0yrs 4mon', '0yrs 5mon', '0yrs 6mon', '0yrs 7mon',
#        '0yrs 8mon', '0yrs 9mon', '10yrs 0mon', '10yrs 10mon',
#        '10yrs 11mon', '10yrs 1mon', '10yrs 2mon', '10yrs 3mon',
#        '10yrs 4mon', '10yrs 6mon', '10yrs 7mon', '10yrs 8mon',
#        '10yrs 9mon', '11yrs 0mon', '11yrs 10mon', '11yrs 11mon',
#        '11yrs 1mon', '11yrs 2mon', '11yrs 3mon', '11yrs 4mon',
#        '11yrs 6mon', '11yrs 7mon', '11yrs 8mon', '11yrs 9mon',
#        '12yrs 0mon', '12yrs 10mon', '12yrs 3mon', '12yrs 6mon',
#        '12yrs 7mon', '12yrs 9mon', '13yrs 0mon', '13yrs 10mon',
#        '13yrs 1mon', '13yrs 5mon', '13yrs 6mon', '13yrs 7mon',
#        '13yrs 8mon', '14yrs 1mon', '14yrs 3mon', '14yrs 5mon',
#        '14yrs 7mon', '14yrs 8mon', '15yrs 11mon', '15yrs 3mon',
#        '18yrs 11mon', '1yrs 0mon', '1yrs 10mon', '1yrs 11mon',
# ...

# %%
data1["CREDIT.HISTORY.LENGTH"]
# Out:
# 0         0yrs 0mon
# 1        1yrs 11mon
# 2         0yrs 0mon
# 3         1yrs 3mon
# 4         0yrs 0mon
#             ...
# 65530     0yrs 0mon
# 65531     0yrs 0mon
# 65532     0yrs 0mon
# 65533     0yrs 0mon
# 65534     0yrs 0mon
# Name: CREDIT.HISTORY.LENGTH, Length: 65535, dtype: object

# %%
data1["CREDIT.HISTORY.LENGTH"].unique()
# Out:
# array(['0yrs 0mon', '1yrs 11mon', '1yrs 3mon', '2yrs 0mon', '0yrs 2mon',
#        '4yrs 8mon', '1yrs 7mon', '0yrs 7mon', '2yrs 3mon', '2yrs 9mon',
#        '2yrs 1mon', '7yrs 2mon', '0yrs 1mon', '5yrs 6mon', '4yrs 7mon',
#        '1yrs 9mon', '0yrs 11mon', '0yrs 10mon', '5yrs 10mon', '3yrs 1mon',
#        '5yrs 4mon', '4yrs 10mon', '0yrs 4mon', '4yrs 0mon', '3yrs 9mon',
#        '2yrs 11mon', '1yrs 8mon', '5yrs 2mon', '2yrs 10mon', '1yrs 2mon',
#        '1yrs 5mon', '12yrs 10mon', '2yrs 2mon', '3yrs 8mon', '7yrs 5mon',
#        '1yrs 0mon', '4yrs 2mon', '1yrs 10mon', '0yrs 6mon', '3yrs 2mon',
#        '5yrs 1mon', '4yrs 3mon', '6yrs 9mon', '1yrs 1mon', '11yrs 0mon',
#        '0yrs 9mon', '5yrs 0mon', '11yrs 2mon', '4yrs 1mon', '1yrs 4mon',
#        '4yrs 9mon', '12yrs 11mon', '3yrs 7mon', '2yrs 5mon', '0yrs 3mon',
#        '6yrs 6mon', '1yrs 6mon', '7yrs 4mon', '19yrs 3mon', '3yrs 0mon',
#        '4yrs 6mon', '2yrs 7mon', '2yrs 8mon', '3yrs 11mon', '4yrs 11mon',
# ...

# %%
encoder=p.LabelEncoder()

# %%
encoder.fit(data1["CREDIT.HISTORY.LENGTH"])
# Out:
# LabelEncoder()

# %%
encoder.transform(data1["CREDIT.HISTORY.LENGTH"])
# Out:
# array([  0, 116,   0, ...,   0,   0,   0])

# %%
coded=encoder.transform(data1["CREDIT.HISTORY.LENGTH"])

# %%
coded
# Out:
# array([  0, 116,   0, ...,   0,   0,   0])

# %%
encoder.inverse_transform(coded)
# Out:
# array(['0yrs 0mon', '1yrs 11mon', '0yrs 0mon', ..., '0yrs 0mon',
#        '0yrs 0mon', '0yrs 0mon'], dtype=object)

# %%
encoder.classes_
# Out:
# array(['0yrs 0mon', '0yrs 10mon', '0yrs 11mon', '0yrs 1mon', '0yrs 2mon',
#        '0yrs 3mon', '0yrs 4mon', '0yrs 5mon', '0yrs 6mon', '0yrs 7mon',
#        '0yrs 8mon', '0yrs 9mon', '10yrs 0mon', '10yrs 10mon',
#        '10yrs 11mon', '10yrs 1mon', '10yrs 2mon', '10yrs 3mon',
#        '10yrs 4mon', '10yrs 5mon', '10yrs 6mon', '10yrs 7mon',
#        '10yrs 8mon', '10yrs 9mon', '11yrs 0mon', '11yrs 10mon',
#        '11yrs 11mon', '11yrs 1mon', '11yrs 2mon', '11yrs 3mon',
#        '11yrs 4mon', '11yrs 5mon', '11yrs 6mon', '11yrs 7mon',
#        '11yrs 8mon', '11yrs 9mon', '12yrs 0mon', '12yrs 10mon',
#        '12yrs 11mon', '12yrs 1mon', '12yrs 2mon', '12yrs 3mon',
#        '12yrs 4mon', '12yrs 5mon', '12yrs 6mon', '12yrs 7mon',
#        '12yrs 8mon', '12yrs 9mon', '13yrs 0mon', '13yrs 10mon',
#        '13yrs 11mon', '13yrs 1mon', '13yrs 2mon', '13yrs 3mon',
#        '13yrs 4mon', '13yrs 5mon', '13yrs 6mon', '13yrs 7mon',
# ...

# %%
data1
# Out:
#        UniqueID  disbursed_amount  asset_cost    ltv  branch_id  supplier_id  \
# 0        420825             50578       58400  89.55         67        22807
# 1        537409             47145       65550  73.23         67        22807
# 2        417566             53278       61360  89.63         67        22807
# 3        624493             57513       66113  88.48         67        22807
# 4        539055             52378       60300  88.39         67        22807
# ...         ...               ...         ...    ...        ...          ...
# 65530    464908             52303       64541  83.67          9        16120
# 65531    434034             52803       68929  78.34          9        16120
# 65532    433849             52999       74740  76.26          9        16120
# 65533    559443             57259       82172  70.58          9        16120
# 65534    626508             62213       82172  76.67          9        16120
#
# ...

# %%
data1.dtypes
# Out:
# UniqueID                                 int64
# disbursed_amount                         int64
# asset_cost                               int64
# ltv                                    float64
# branch_id                                int64
# supplier_id                              int64
# manufacturer_id                          int64
# Current_pincode_ID                       int64
# State_ID                                 int64
# Employee_code_ID                         int64
# MobileNo_Avl_Flag                        int64
# Aadhar_flag                              int64
# PAN_flag                                 int64
# VoterID_flag                             int64
# Driving_flag                             int64
# Passport_flag                            int64
# PERFORM_CNS.SCORE                        int64
# PERFORM_CNS.SCORE.DESCRIPTION           object
# PRI.NO.OF.ACCTS                          int64
# PRI.ACTIVE.ACCTS                         int64
# ...
